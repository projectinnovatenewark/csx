# %% [markdown]
# ## Welcome!
#
# Prior to coming to class please create a gmail account.
#
# In this submodule you will learn about Data Science and Python Programming. We will start with the basics of programming, dive into working with data, and end with an introduction of applied Machine Learning.

# %% [markdown]
# To begin, open your laptops and and open a chrome browser (or the browser installed on the school laptop). Use this link:
# https://www.bing.com/ck/a?!&&p=5907a5fcf19175fdJmltdHM9MTY4Nzk5NjgwMCZpZ3VpZD0xZTEwMzZkMS04MzQ1LTYwZTAtMWYwZi0yNjFkODI2YzYxODQmaW5zaWQ9NTE5Nw&ptn=3&hsh=3&fclid=1e1036d1-8345-60e0-1f0f-261d826c6184&psq=replit&u=a1aHR0cHM6Ly9yZXBsaXQuY29tLw&ntb=1
# This will take you to replit, the online IDE (Integrated Development Environment) we will be using to run our code.

# %% [markdown]
# Go to the sign-up button at the top right of the screen to create a replit account. Hit 'Continue with Google' and choose the gmail account you created. If prompted sign into the account. You should now be in replit.

# %% [markdown]
# On the top left of the screen, hit the 'Create Repl' button. Choose the template named 'Python' and give the repl the name 'DataScienceLessons'. Your screen should look like this.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Hit 'Create Repl' to move to your coding space. You should be in a file named 'main.py'.

# %% [markdown]
# Near the top left of the screen next to 'Files', you should see two buttons. The first button allows you to create files of various types and the second button allows you to create a folder.

# %% [markdown]
# Now let's learn some Python fundamentals. You can follow along by typing the code inside of the 'main.py' file you just created. Click on each of the links below to find the lessons for each topic.

# %% [markdown]
# ### Intro to Variables & Types
#
# Link: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/1_basics/2_vars_and_types/2_variables_and_types.ipynb
#
#
# Todos: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/1_basics/2_vars_and_types/2R_variables_and_typestodo.ipynb

# %% [markdown]
# ### String Manipulation (Section 1 and 4 only)
#
# Link: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/1_basics/3_string_manipulation/3_string_manipulation.ipynb

# %% [markdown]
# ### Packages
#
# Link: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/1_basics/7_imports/7_imports.ipynb
#
# Todo: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/1_basics/7_imports/7_importstodo.ipynb

# %% [markdown]
# ### Complex Types
#
# Link: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/1_basics/5_lists_and_dicts/5_lists_and_dicts.ipynb
#
# Todo: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/1_basics/5_lists_and_dicts/5_lists_and_dictstodo.ipynb

# %% [markdown]
# ### Conditions
#
# Link: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/1_basics/10_conditionals_and_while_loops/10_conditionals_and_while_loops.ipynb
#
# Todo: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/1_basics/10_conditionals_and_while_loops/10_conditionals_and_while_loopstodo.ipynb

# %% [markdown]
# ### For-Loops

# %% [markdown]
# Link: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/1_basics/9_indexing_and_for_loops/9_indexing_and_for_loops.ipynb
#
# Todos: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/1_basics/9_indexing_and_for_loops/9_indexing_and_for_loopstodo.ipynb

# %% [markdown]
# ### Functions
#
# Link: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/2_functions_and_conditions/11_functions_and_scope/11_functions_and_scope.ipynb
#
# Todos: https://github.com/projectinnovatenewark/csx/blob/main/Students/Semester2/lessons/students/2_functions_and_conditions/11_functions_and_scope/11_functions_and_scopetodo.ipynb
